# %%
import sys
import os

# Add the scripts folder to the sys.path
sys.path.append(os.path.abspath('E:/Git_repo/time_series_credit_risk/scripts'))

# %%
# Import necessary modules
from data_loader import load_data
from eda import clean_data, summary_statistics, missing_values, visualize_data, correlation_heatmap, missing_data_visualization, plot_histograms, plot_boxplots, seasonal_decomposition, autocorrelation_plots

# %%
# Load the raw data
file_path = "E:/data/Data11/preprocessed_financial_data.csv"
df = load_data(file_path)

# Clean the data
df_cleaned = clean_data(df)
# Out:
# E:\Git_repo\time_series_credit_risk\scripts\data_loader.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.read_csv(file_path, parse_dates=True, index_col=0)

# %%
# Print summary statistics and check for missing values
summary_statistics(df_cleaned)
# Out:
#        A d j   C l o s e    C l o s e C l o s e . 1 C l o s e . 2  \
# count                  1         2536          2536             1
# unique                 1         2310          2496             1
# top                 TSLA  62.69594955   189.0302887          TSLA
# freq                   1            5             2             1
#
#             H i g h  H i g h . 1 H i g h . 2        L o w    L o w . 1  \
# count          2536         2536           1         2536         2536
# unique         2525         2534           1         2518         2536
# top     72.89890757  188.1217208        TSLA  63.07617376  600.7199707
# freq              2            2           1            3            1
#
#        L o w . 2     O p e n O p e n . 1 O p e n . 2 V o l u m e  \
# count          1        2536        2536           1        2536
# unique         1        2530        2536           1        2491
# top         TSLA  62.8436146  603.960022        TSLA     1827800
# ...

# %%
# Print summary statistics and check for missing values
missing_values(df_cleaned)
# Out:
# Missing Values:
#  A d j   C l o s e    2536
# C l o s e               1
# C l o s e . 1           1
# C l o s e . 2        2536
# H i g h                 1
# H i g h . 1             1
# H i g h . 2          2536
# L o w                   1
# L o w . 1               1
# L o w . 2            2536
# O p e n                 1
# O p e n . 1             1
# O p e n . 2          2536
# V o l u m e             1
# V o l u m e . 1         1
# V o l u m e . 2      2536
# dtype: int64

# %%
# Visualize the data
visualize_data(df_cleaned)  # This will include the historical trend visualization
# Out:
# E:\Git_repo\time_series_credit_risk\scripts\eda.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.index = pd.to_datetime(df.index, errors='coerce')

# %%
# Additional visualizations
correlation_heatmap(df_cleaned)  # Visualize correlation between numerical features

# %%
missing_data_visualization(df_cleaned)  # Visualize missing data

# %%
plot_histograms(df_cleaned)  # Visualize histograms of numeric features

# %%
plot_boxplots(df_cleaned)  # Visualize boxplots to detect outliers

# %%
seasonal_decomposition(df, "Close", period=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 seasonal_decomposition(df_cleaned)
#
# TypeError: seasonal_decomposition() missing 1 required positional argument: 'column'

# %%
# Example usage:
autocorrelation_plots(df, df_cleaned)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18364\3661921227.py in ?()
# ----> 2 # Example usage:
#       3 autocorrelation_plots(df, df_cleaned)
#
# E:\Git_repo\time_series_credit_risk\scripts\eda.py in ?(df, column)
#      81 def autocorrelation_plots(df, column):
#      82     """Plot autocorrelation and partial autocorrelation."""
# ---> 83     df[column] = pd.to_numeric(df[column], errors='coerce')
#      84
#      85     plt.figure(figsize=(12, 6))
#      86     plot_acf(df[column], lags=50)
#
# e:\Git_repo\time_series_credit_risk\tsvenv\lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4085             return self._getitem_slice(key)
#    4086
#    4087         # Do we have a (boolean) DataFrame?
#    4088         if isinstance(key, DataFrame):
# -> 4089             return self.where(key)
#    4090
# ...
