# %%
import sys
import os

# Add the scripts folder to the sys.path
sys.path.append(os.path.abspath('E:/Git_repo/time_series_credit_risk/scripts'))

# %%
# Import necessary modules
from data_loader import load_data
from eda import clean_data, summary_statistics, missing_values, visualize_data, correlation_heatmap, missing_data_visualization, plot_histograms, plot_boxplots, seasonal_decomposition, autocorrelation_plots

# %%
# Load the raw data
file_path = "E:/data/Data11/preprocessed_financial_data.csv"
df = load_data(file_path)

# Clean the data
df_cleaned = clean_data(df)
# Out:
# E:\Git_repo\time_series_credit_risk\scripts\data_loader.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.read_csv(file_path, parse_dates=True, index_col=0)

# %%
# Print summary statistics and check for missing values
summary_statistics(df_cleaned)
missing_values(df_cleaned)
# Out:
#        A   d   j       C   l   o   s   e  C   l   o   s   e  \
# count                                  1               2536
# unique                                 1               2310
# top                                 TSLA  62.69594955444336
# freq                                   1                  5
#
#        C   l   o   s   e   .   1 C   l   o   s   e   .   2      H   i   g   h  \
# count                       2536                         1               2536
# unique                      2496                         1               2525
# top           189.03028869628906                      TSLA  72.89890757491155
# freq                           2                         1                  2
#
#        H   i   g   h   .   1 H   i   g   h   .   2          L   o   w  \
# count                   2536                     1               2536
# unique                  2534                     1               2518
# top       188.12172081677426                  TSLA  63.07617375536817
# freq                       2                     1                  3
#
#        L   o   w   .   1 L   o   w   .   2      O   p   e   n  \
# count               2536                 1               2536
# unique              2536                 1               2530
# top     600.719970703125              TSLA  62.84361459837238
# freq                   1                 1                  2
#
#        O   p   e   n   .   1 O   p   e   n   .   2 V   o   l   u   m   e  \
# count                   2536                     1                  2536
# unique                  2536                     1                  2491
# top        603.9600219726562                  TSLA               1827800
# freq                       1                     1                     3
#
#        V   o   l   u   m   e   .   1 V   o   l   u   m   e   .   2
# count                           2536                             1
# unique                          2534                             1
# top                         89351900                          TSLA
# freq                               2                             1
# Missing Values:
#  A   d   j       C   l   o   s   e    2536
# C   l   o   s   e                       1
# C   l   o   s   e   .   1               1
# C   l   o   s   e   .   2            2536
# H   i   g   h                           1
# H   i   g   h   .   1                   1
# H   i   g   h   .   2                2536
# L   o   w                               1
# L   o   w   .   1                       1
# L   o   w   .   2                    2536
# O   p   e   n                           1
# O   p   e   n   .   1                   1
# O   p   e   n   .   2                2536
# V   o   l   u   m   e                   1
# V   o   l   u   m   e   .   1           1
# V   o   l   u   m   e   .   2        2536
# dtype: int64

# %%
# Visualize the data
visualize_data(df_cleaned)  # This will include the historical trend visualization
# Out:
# E:\Git_repo\time_series_credit_risk\scripts\eda.py:26: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.index = pd.to_datetime(df.index, errors='coerce')

# %%
# Additional visualizations
correlation_heatmap(df_cleaned)  # Visualize correlation between numerical features

# %%
missing_data_visualization(df_cleaned)  # Visualize missing data

# %%
plot_histograms(df_cleaned)  # Visualize histograms of numeric features

# %%
plot_boxplots(df_cleaned)  # Visualize boxplots to detect outliers

# %%
seasonal_decomposition(df_cleaned)

# %%
# Example usage:
autocorrelation_plots(df, 'your_column_name_here')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Example usage:
# ----> 2 autocorrelation_plots(df, 'your_column_name_here')
#
# NameError: name 'autocorrelation_plots' is not defined
